# %% [markdown]
# ## Imports und Konfiguration

# %%
import os
import shutil
import pandas as pd
import random


random.seed(42)

# Anteil der Testdaten
test_split_percentage = 0.2


image_dir = r"C:\Users\bracke\Documents\all"
output_base = r"C:\Users\bracke\Documents\all_split"


df_path = r"C:\Users\bracke\Documents\df_mit_hospital.csv"
df = pd.read_csv(df_path)
df["Patient ID"] = df["Patient ID"].astype(str).str.strip()

# %% [markdown]
# ## Krankenhaus-Zuordnung festlegen

# %%
hospital_1 = os.path.join(output_base, "Krankenhaus_1")
hospital_2 = os.path.join(output_base, "Krankenhaus_2")
hospital_3 = os.path.join(output_base, "Krankenhaus_3")


test_hospital_1 = os.path.join(output_base, "Test_1")
test_hospital_2 = os.path.join(output_base, "Test_2")
test_hospital_3 = os.path.join(output_base, "Test_3")


for test_dir in [test_hospital_1, test_hospital_2, test_hospital_3]:
    os.makedirs(test_dir, exist_ok=True)

# %% [markdown]
# ## Funktion zum Splitten der Testdaten

# %%
def split_test_data(df_hospital, percentage):
    test_size = int(len(df_hospital) * percentage)
    test_data = df_hospital.sample(n=test_size, random_state=42)
    return test_data

# %% [markdown]
# ## Anwendung des Splits auf jedes Krankenhaus

# %%
test_1 = split_test_data(df[df["Target Hospital"] == hospital_1], test_split_percentage)
test_2 = split_test_data(df[df["Target Hospital"] == hospital_2], test_split_percentage)
test_3 = split_test_data(df[df["Target Hospital"] == hospital_3], test_split_percentage)

test_df = pd.concat([test_1, test_2, test_3])

# %% [markdown]
# ## Bilder in Testordner kopieren

# %%
for _, row in test_df.iterrows():
    patient_id = row["Patient ID"]
    target_hospital = row["Target Hospital"]

    if target_hospital == hospital_1:
        dest_dir = test_hospital_1
    elif target_hospital == hospital_2:
        dest_dir = test_hospital_2
    elif target_hospital == hospital_3:
        dest_dir = test_hospital_3
    else:
        print(f"Kein Zielkrankenhaus für Patient {patient_id}")
        continue

   
    matching_folders = [f for f in os.listdir(image_dir) if f.startswith(patient_id)]
    if not matching_folders:
        print(f" Kein Ordner für Patient {patient_id}. Überspringe.")
        continue

 
    for folder_name in matching_folders:
        src_file = os.path.join(image_dir, folder_name, "sub.nii.gz")
        if not os.path.exists(src_file):
            print(f" Bild fehlt: {src_file}. Überspringe.")
            continue

        dest_file = os.path.join(dest_dir, f"{folder_name}.nii.gz")
        if os.path.exists(dest_file):
            print(f" Bereits vorhanden: {dest_file}. Überspringe.")
            continue

        shutil.copy(src_file, dest_file)
        print(f"Kopiert: {src_file} → {dest_file}")
# Out:
#  Kein Ordner für Patient Breast_MRI_086. Überspringe.
#  Kein Ordner für Patient Breast_MRI_022. Überspringe.
#  Kein Ordner für Patient Breast_MRI_409. Überspringe.
#  Kein Ordner für Patient Breast_MRI_864. Überspringe.
#  Kein Ordner für Patient Breast_MRI_782. Überspringe.
#  Kein Ordner für Patient Breast_MRI_327. Überspringe.
#  Kein Ordner für Patient Breast_MRI_266. Überspringe.
#  Kein Ordner für Patient Breast_MRI_601. Überspringe.
#  Kein Ordner für Patient Breast_MRI_268. Überspringe.
#  Kein Ordner für Patient Breast_MRI_101. Überspringe.
#  Kein Ordner für Patient Breast_MRI_189. Überspringe.
#  Kein Ordner für Patient Breast_MRI_112. Überspringe.
#  Kein Ordner für Patient Breast_MRI_479. Überspringe.
#  Kein Ordner für Patient Breast_MRI_131. Überspringe.
#  Kein Ordner für Patient Breast_MRI_293. Überspringe.
#  Kein Ordner für Patient Breast_MRI_679. Überspringe.
#  Kein Ordner für Patient Breast_MRI_139. Überspringe.
#  Kein Ordner für Patient Breast_MRI_544. Überspringe.
#  Kein Ordner für Patient Breast_MRI_613. Überspringe.
#  Kein Ordner für Patient Breast_MRI_015. Überspringe.
#  Kein Ordner für Patient Breast_MRI_824. Überspringe.
#  Kein Ordner für Patient Breast_MRI_731. Überspringe.
#  Kein Ordner für Patient Breast_MRI_647. Überspringe.
#  Kein Ordner für Patient Breast_MRI_282. Überspringe.
#  Kein Ordner für Patient Breast_MRI_819. Überspringe.
#  Kein Ordner für Patient Breast_MRI_202. Überspringe.
#  Kein Ordner für Patient Breast_MRI_140. Überspringe.
#  Kein Ordner für Patient Breast_MRI_529. Überspringe.
#  Kein Ordner für Patient Breast_MRI_844. Überspringe.
#  Kein Ordner für Patient Breast_MRI_181. Überspringe.
#  Kein Ordner für Patient Breast_MRI_596. Überspringe.
#  Kein Ordner für Patient Breast_MRI_335. Überspringe.
#  Kein Ordner für Patient Breast_MRI_791. Überspringe.
#  Kein Ordner für Patient Breast_MRI_410. Überspringe.
#  Kein Ordner für Patient Breast_MRI_106. Überspringe.
#  Kein Ordner für Patient Breast_MRI_324. Überspringe.
#  Kein Ordner für Patient Breast_MRI_143. Überspringe.
#  Kein Ordner für Patient Breast_MRI_645. Überspringe.
#  Kein Ordner für Patient Breast_MRI_907. Überspringe.
#  Kein Ordner für Patient Breast_MRI_904. Überspringe.
#  Kein Ordner für Patient Breast_MRI_195. Überspringe.
#  Kein Ordner für Patient Breast_MRI_886. Überspringe.
#  Kein Ordner für Patient Breast_MRI_072. Überspringe.
#  Kein Ordner für Patient Breast_MRI_171. Überspringe.
#  Kein Ordner für Patient Breast_MRI_849. Überspringe.
#  Kein Ordner für Patient Breast_MRI_506. Überspringe.
#  Kein Ordner für Patient Breast_MRI_850. Überspringe.
#  Kein Ordner für Patient Breast_MRI_577. Überspringe.
#  Kein Ordner für Patient Breast_MRI_082. Überspringe.
#  Kein Ordner für Patient Breast_MRI_057. Überspringe.
#  Kein Ordner für Patient Breast_MRI_718. Überspringe.
#  Kein Ordner für Patient Breast_MRI_067. Überspringe.
#  Kein Ordner für Patient Breast_MRI_437. Überspringe.
#  Kein Ordner für Patient Breast_MRI_176. Überspringe.
#  Kein Ordner für Patient Breast_MRI_210. Überspringe.
#  Kein Ordner für Patient Breast_MRI_379. Überspringe.
#  Kein Ordner für Patient Breast_MRI_042. Überspringe.
#  Kein Ordner für Patient Breast_MRI_307. Überspringe.
#  Kein Ordner für Patient Breast_MRI_050. Überspringe.
#  Kein Ordner für Patient Breast_MRI_821. Überspringe.
#  Kein Ordner für Patient Breast_MRI_317. Überspringe.
#  Kein Ordner für Patient Breast_MRI_807. Überspringe.
#  Kein Ordner für Patient Breast_MRI_511. Überspringe.
#  Kein Ordner für Patient Breast_MRI_491. Überspringe.
#  Kein Ordner für Patient Breast_MRI_066. Überspringe.
#  Kein Ordner für Patient Breast_MRI_395. Überspringe.
#  Kein Ordner für Patient Breast_MRI_348. Überspringe.
#  Kein Ordner für Patient Breast_MRI_610. Überspringe.
#  Kein Ordner für Patient Breast_MRI_774. Überspringe.
#  Kein Ordner für Patient Breast_MRI_712. Überspringe.
#  Kein Ordner für Patient Breast_MRI_602. Überspringe.
#  Kein Ordner für Patient Breast_MRI_337. Überspringe.
#  Kein Ordner für Patient Breast_MRI_753. Überspringe.
#  Kein Ordner für Patient Breast_MRI_701. Überspringe.
#  Kein Ordner für Patient Breast_MRI_806. Überspringe.
#  Kein Ordner für Patient Breast_MRI_083. Überspringe.
#  Kein Ordner für Patient Breast_MRI_220. Überspringe.
#  Kein Ordner für Patient Breast_MRI_777. Überspringe.
#  Kein Ordner für Patient Breast_MRI_438. Überspringe.
#  Kein Ordner für Patient Breast_MRI_906. Überspringe.
#  Kein Ordner für Patient Breast_MRI_914. Überspringe.
#  Kein Ordner für Patient Breast_MRI_817. Überspringe.
#  Kein Ordner für Patient Breast_MRI_618. Überspringe.
#  Kein Ordner für Patient Breast_MRI_458. Überspringe.
#  Kein Ordner für Patient Breast_MRI_161. Überspringe.
#  Kein Ordner für Patient Breast_MRI_118. Überspringe.
#  Kein Ordner für Patient Breast_MRI_735. Überspringe.
#  Kein Ordner für Patient Breast_MRI_071. Überspringe.
#  Kein Ordner für Patient Breast_MRI_258. Überspringe.
#  Kein Ordner für Patient Breast_MRI_575. Überspringe.
#  Kein Ordner für Patient Breast_MRI_658. Überspringe.
#  Kein Ordner für Patient Breast_MRI_418. Überspringe.
#  Kein Ordner für Patient Breast_MRI_329. Überspringe.
#  Kein Ordner für Patient Breast_MRI_873. Überspringe.
#  Kein Ordner für Patient Breast_MRI_713. Überspringe.
#  Kein Ordner für Patient Breast_MRI_633. Überspringe.
#  Kein Ordner für Patient Breast_MRI_434. Überspringe.
#  Kein Ordner für Patient Breast_MRI_383. Überspringe.
#  Kein Ordner für Patient Breast_MRI_449. Überspringe.
#  Kein Ordner für Patient Breast_MRI_837. Überspringe.
#  Kein Ordner für Patient Breast_MRI_834. Überspringe.
#  Kein Ordner für Patient Breast_MRI_823. Überspringe.
#  Kein Ordner für Patient Breast_MRI_858. Überspringe.
#  Kein Ordner für Patient Breast_MRI_898. Überspringe.
#  Kein Ordner für Patient Breast_MRI_848. Überspringe.
#  Kein Ordner für Patient Breast_MRI_213. Überspringe.
#  Kein Ordner für Patient Breast_MRI_630. Überspringe.
#  Kein Ordner für Patient Breast_MRI_345. Überspringe.
#  Kein Ordner für Patient Breast_MRI_254. Überspringe.
#  Kein Ordner für Patient Breast_MRI_205. Überspringe.
#  Kein Ordner für Patient Breast_MRI_302. Überspringe.
#  Kein Ordner für Patient Breast_MRI_325. Überspringe.
#  Kein Ordner für Patient Breast_MRI_789. Überspringe.
#  Kein Ordner für Patient Breast_MRI_150. Überspringe.
#  Kein Ordner für Patient Breast_MRI_312. Überspringe.
#  Kein Ordner für Patient Breast_MRI_861. Überspringe.
#  Kein Ordner für Patient Breast_MRI_152. Überspringe.
#  Kein Ordner für Patient Breast_MRI_687. Überspringe.
#  Kein Ordner für Patient Breast_MRI_842. Überspringe.
#  Kein Ordner für Patient Breast_MRI_236. Überspringe.
#  Kein Ordner für Patient Breast_MRI_296. Überspringe.
#  Kein Ordner für Patient Breast_MRI_029. Überspringe.
#  Kein Ordner für Patient Breast_MRI_859. Überspringe.
#  Kein Ordner für Patient Breast_MRI_339. Überspringe.
#  Kein Ordner für Patient Breast_MRI_751. Überspringe.
#  Kein Ordner für Patient Breast_MRI_903. Überspringe.
#  Kein Ordner für Patient Breast_MRI_543. Überspringe.
#  Kein Ordner für Patient Breast_MRI_247. Überspringe.
#  Kein Ordner für Patient Breast_MRI_255. Überspringe.
#  Kein Ordner für Patient Breast_MRI_413. Überspringe.
#  Kein Ordner für Patient Breast_MRI_077. Überspringe.
#  Kein Ordner für Patient Breast_MRI_346. Überspringe.
#  Kein Ordner für Patient Breast_MRI_277. Überspringe.
#  Kein Ordner für Patient Breast_MRI_229. Überspringe.
#  Kein Ordner für Patient Breast_MRI_088. Überspringe.
#  Kein Ordner für Patient Breast_MRI_685. Überspringe.
#  Kein Ordner für Patient Breast_MRI_676. Überspringe.
#  Kein Ordner für Patient Breast_MRI_916. Überspringe.
#  Kein Ordner für Patient Breast_MRI_520. Überspringe.
#  Kein Ordner für Patient Breast_MRI_838. Überspringe.
#  Kein Ordner für Patient Breast_MRI_035. Überspringe.
#  Kein Ordner für Patient Breast_MRI_737. Überspringe.
#  Kein Ordner für Patient Breast_MRI_002. Überspringe.
#  Kein Ordner für Patient Breast_MRI_745. Überspringe.
#  Kein Ordner für Patient Breast_MRI_648. Überspringe.
#  Kein Ordner für Patient Breast_MRI_310. Überspringe.
#  Kein Ordner für Patient Breast_MRI_646. Überspringe.
#  Kein Ordner für Patient Breast_MRI_439. Überspringe.
#  Kein Ordner für Patient Breast_MRI_652. Überspringe.
#  Kein Ordner für Patient Breast_MRI_836. Überspringe.
#  Kein Ordner für Patient Breast_MRI_525. Überspringe.
#  Kein Ordner für Patient Breast_MRI_831. Überspringe.
#  Kein Ordner für Patient Breast_MRI_841. Überspringe.
#  Kein Ordner für Patient Breast_MRI_650. Überspringe.
#  Kein Ordner für Patient Breast_MRI_419. Überspringe.
#  Kein Ordner für Patient Breast_MRI_216. Überspringe.
#  Kein Ordner für Patient Breast_MRI_114. Überspringe.
#  Kein Ordner für Patient Breast_MRI_399. Überspringe.
#  Kein Ordner für Patient Breast_MRI_226. Überspringe.
#  Kein Ordner für Patient Breast_MRI_107. Überspringe.
#  Kein Ordner für Patient Breast_MRI_902. Überspringe.
#  Kein Ordner für Patient Breast_MRI_064. Überspringe.
#  Kein Ordner für Patient Breast_MRI_378. Überspringe.
#  Kein Ordner für Patient Breast_MRI_425. Überspringe.
#  Kein Ordner für Patient Breast_MRI_814. Überspringe.
#  Kein Ordner für Patient Breast_MRI_636. Überspringe.
#  Kein Ordner für Patient Breast_MRI_060. Überspringe.
#  Kein Ordner für Patient Breast_MRI_129. Überspringe.
#  Kein Ordner für Patient Breast_MRI_228. Überspringe.
#  Kein Ordner für Patient Breast_MRI_373. Überspringe.
#  Kein Ordner für Patient Breast_MRI_233. Überspringe.
#  Kein Ordner für Patient Breast_MRI_219. Überspringe.
#  Kein Ordner für Patient Breast_MRI_154. Überspringe.
#  Kein Ordner für Patient Breast_MRI_285. Überspringe.
#  Kein Ordner für Patient Breast_MRI_062. Überspringe.
#  Kein Ordner für Patient Breast_MRI_045. Überspringe.
#  Kein Ordner für Patient Breast_MRI_565. Überspringe.
#  Kein Ordner für Patient Breast_MRI_909. Überspringe.
#  Kein Ordner für Patient Breast_MRI_078. Überspringe.
#  Kein Ordner für Patient Breast_MRI_673. Überspringe.
#  Kein Ordner für Patient Breast_MRI_381. Überspringe.
#  Kein Ordner für Patient Breast_MRI_473. Überspringe.

# %% [markdown]
# ## Exportieren und Zusammenfassung

# %%
test_df.to_csv(r"C:\Users\bracke\Documents\df_test.csv", index=False)


print("Testdatensplit abgeschlossen.")
print("Testdatensatz-Übersicht:")
print(f"Krankenhaus 1 (Test_1): {len(test_1)} Patient:innen")
print(f"Krankenhaus 2 (Test_2): {len(test_2)} Patient:innen")
print(f"Krankenhaus 3 (Test_3): {len(test_3)} Patient:innen")
print(f"Gesamt: {len(test_df)} Test-Patient:innen")
# Out:
# Testdatensplit abgeschlossen.
# Testdatensatz-Übersicht:
# Krankenhaus 1 (Test_1): 58 Patient:innen
# Krankenhaus 2 (Test_2): 42 Patient:innen
# Krankenhaus 3 (Test_3): 82 Patient:innen
# Gesamt: 182 Test-Patient:innen
