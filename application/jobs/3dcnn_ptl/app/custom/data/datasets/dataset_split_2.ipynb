# %%
import os
import shutil
import pandas as pd
import numpy as np

# %% [markdown]
# ## Pfade für Verzeichnisse

# %%
image_dir = r"C:\Users\bracke\Documents\all"
excel_path = r"C:\Users\bracke\Documents\Clinical_and_Other_Features.xlsx"
output_base = r"C:\Users\bracke\Documents\all_split"


hospital_1 = os.path.join(output_base, "Krankenhaus_1")  # M2
hospital_2 = os.path.join(output_base, "Krankenhaus_2")  # M0.1
hospital_3 = os.path.join(output_base, "Krankenhaus_3")  # M0.2


for hospital in [hospital_1, hospital_2, hospital_3]:
    os.makedirs(hospital, exist_ok=True)

# %% [markdown]
# ##  Lade und bereinige die Excel-Daten

# %%
df = pd.read_excel(excel_path, header=1)  
df = df[["Patient ID", "Manufacturer", "Bilateral Information", "Tumor Location"]]
df.dropna(subset=["Patient ID", "Manufacturer"], inplace=True)


df["Patient ID"] = df["Patient ID"].astype(str).str.strip()  
df["Manufacturer"] = df["Manufacturer"].astype(int)

def normalize_bilateral(val):
    if pd.isna(val):
        return "NC"  
    if isinstance(val, str):
        return val.strip().upper()  
    if isinstance(val, (int, float)):
        return int(val)  
    return str(val).upper()  

df["Bilateral Information"] = df["Bilateral Information"].apply(normalize_bilateral)

# %% [markdown]
# ## Zuweisung der Zielkrankenhäuser

# %%
df["Target Hospital"] = None

# Krankenhaus 1: Alle Patienten von Manufacturer 2
df.loc[df["Manufacturer"] == 2, "Target Hospital"] = hospital_1

# Beidseitige Krebsfälle für Krankenhaus 2 (Bilateral Information == 1)
bilateral_cancer_cases = df[(df["Bilateral Information"] == 1) & (df["Manufacturer"] == 0)]

# Einseitige Krebsfälle für Krankenhaus 2 (L-Krebs und R-Krebs)
left_cancer_cases = df[(df["Tumor Location"] == "L") & (df["Manufacturer"] == 0) & (df["Bilateral Information"] == 0)]
right_cancer_cases = df[(df["Tumor Location"] == "R") & (df["Manufacturer"] == 0) & (df["Bilateral Information"] == 0)]

n_left = len(left_cancer_cases)
n_right = len(right_cancer_cases)

left_cancer_split = left_cancer_cases.sample(n=n_left//2, random_state=42)  
right_cancer_split = right_cancer_cases.sample(n=int(np.ceil(n_right / 2)), random_state=42)  

#  Krankenhaus 2: Beidseitige Krebsfälle und zufällig ausgewählte L und R Krebsfälle
df.loc[df["Patient ID"].isin(bilateral_cancer_cases["Patient ID"]), "Target Hospital"] = hospital_2
df.loc[df["Patient ID"].isin(left_cancer_split["Patient ID"]), "Target Hospital"] = hospital_2
df.loc[df["Patient ID"].isin(right_cancer_split["Patient ID"]), "Target Hospital"] = hospital_2

# Krankenhaus 3: Patienten ohne Krebs und die andere Hälfte der einseitigen Krebsfälle
no_cancer = df[(df["Bilateral Information"] == "NC") & (df["Manufacturer"] == 0)]

# no_cancer = df[df["Tumor Location"] == "NC"]  
remaining_left_cancer_cases = left_cancer_cases.drop(left_cancer_split.index)  
remaining_right_cancer_cases = right_cancer_cases.drop(right_cancer_split.index) 

print(len(remaining_left_cancer_cases), len(remaining_right_cancer_cases))

df.loc[df["Patient ID"].isin(no_cancer["Patient ID"]), "Target Hospital"] = hospital_3
df.loc[df["Patient ID"].isin(remaining_left_cancer_cases["Patient ID"]), "Target Hospital"] = hospital_3
df.loc[df["Patient ID"].isin(remaining_right_cancer_cases["Patient ID"]), "Target Hospital"] = hospital_3
# Out:
# 98 102

# %% [markdown]
# ## Bilder kopieren

# %%
for _, row in df.iterrows():
    patient_id = row["Patient ID"]
    target_dir = row["Target Hospital"]

    if pd.isna(target_dir):
        print(f"Kein Zielkrankenhaus für Patient {patient_id} definiert. Überspringe")
        continue

    matching_folders = [f for f in os.listdir(image_dir) if f.startswith(patient_id)]
    if not matching_folders:
        print(f"Kein Ordner für Patient {patient_id} gefunden. Überspringe")
        continue

    for folder_name in matching_folders:
        folder_path = os.path.join(image_dir, folder_name)
        src_file = os.path.join(folder_path, "sub.nii.gz")
        if not os.path.exists(src_file):
            print(f"Bild fehlt in {folder_path}. Überspringe")
            continue

        new_filename = f"{folder_name}.nii.gz"
        dest_file = os.path.join(target_dir, new_filename)

        if os.path.exists(dest_file):
            print(f"Bild {new_filename} existiert bereits in {target_dir}. Überspringe")
            continue

        shutil.copy(src_file, dest_file)
        print(f" Kopiert: {src_file} → {dest_file}")

print("Verteilung abgeschlossen")
# Out:
# Kein Ordner für Patient Breast_MRI_001 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_002 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_003 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_004 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_005 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_006 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_007 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_008 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_009 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_010 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_011 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_012 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_013 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_014 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_015 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_016 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_017 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_018 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_019 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_020 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_021 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_022 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_023 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_024 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_025 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_026 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_027 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_028 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_029 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_030 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_031 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_032 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_033 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_034 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_035 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_036 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_037 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_038 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_039 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_040 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_041 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_042 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_043 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_044 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_045 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_046 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_047 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_048 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_049 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_050 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_051 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_052 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_053 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_054 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_055 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_056 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_057 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_058 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_059 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_060 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_061 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_062 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_063 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_064 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_065 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_066 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_067 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_068 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_069 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_070 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_071 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_072 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_073 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_074 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_075 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_076 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_077 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_078 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_079 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_080 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_081 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_082 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_083 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_084 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_085 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_086 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_087 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_088 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_089 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_090 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_091 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_092 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_093 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_094 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_095 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_096 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_097 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_098 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_099 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_100 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_101 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_102 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_103 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_104 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_105 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_106 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_107 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_108 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_109 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_110 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_111 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_112 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_113 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_114 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_115 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_116 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_117 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_118 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_119 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_120 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_121 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_122 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_123 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_124 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_125 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_126 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_127 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_128 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_129 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_130 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_131 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_132 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_133 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_134 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_135 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_136 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_137 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_138 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_139 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_140 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_141 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_142 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_143 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_144 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_145 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_146 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_147 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_148 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_149 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_150 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_151 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_152 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_153 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_154 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_155 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_156 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_157 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_158 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_159 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_160 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_161 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_162 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_163 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_164 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_165 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_166 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_167 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_168 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_169 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_170 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_171 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_172 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_173 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_174 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_175 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_176 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_177 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_178 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_179 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_180 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_181 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_182 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_183 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_184 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_185 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_186 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_187 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_188 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_189 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_190 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_191 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_192 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_193 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_194 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_195 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_196 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_197 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_198 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_199 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_200 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_201 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_202 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_203 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_204 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_205 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_206 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_207 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_208 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_209 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_210 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_211 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_212 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_213 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_214 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_215 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_216 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_217 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_218 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_219 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_220 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_221 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_222 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_223 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_224 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_225 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_226 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_227 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_228 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_229 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_230 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_231 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_232 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_233 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_234 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_235 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_236 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_237 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_238 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_239 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_240 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_241 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_242 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_243 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_244 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_245 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_246 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_247 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI
gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_643 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_644 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_645 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_646 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_647 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_648 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_649 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_650 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_651 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_652 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_653 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_654 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_655 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_656 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_657 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_658 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_659 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_660 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_661 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_662 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_663 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_664 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_665 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_666 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_667 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_668 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_669 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_670 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_671 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_672 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_673 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_674 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_675 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_676 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_677 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_678 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_679 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_680 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_681 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_682 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_683 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_684 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_685 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_686 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_687 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_688 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_689 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_690 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_691 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_692 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_693 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_694 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_695 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_696 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_697 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_698 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_699 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_700 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_701 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_702 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_703 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_704 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_705 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_706 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_707 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_708 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_709 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_710 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_711 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_712 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_713 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_714 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_715 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_716 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_717 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_718 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_719 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_720 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_721 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_722 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_723 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_724 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_725 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_726 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_727 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_728 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_729 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_730 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_731 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_732 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_733 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_734 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_735 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_736 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_737 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_738 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_739 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_740 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_741 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_742 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_743 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_744 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_745 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_746 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_747 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_748 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_749 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_750 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_751 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_752 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_753 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_754 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_755 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_756 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_757 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_758 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_759 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_760 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_761 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_762 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_763 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_764 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_765 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_766 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_767 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_768 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_769 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_770 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_771 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_772 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_773 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_774 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_775 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_776 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_777 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_778 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_779 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_780 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_781 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_782 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_783 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_784 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_785 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_786 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_787 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_788 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_789 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_790 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_791 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_792 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_793 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_794 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_795 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_796 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_797 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_798 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_799 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_800 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_801 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_802 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_803 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_804 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_805 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_806 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_807 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_808 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_809 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_810 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_811 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_812 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_813 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_814 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_815 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_816 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_817 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_818 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_819 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_820 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_821 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_822 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_823 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_824 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_825 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_826 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_827 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_828 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_829 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_830 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_831 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_832 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_833 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_834 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_835 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_836 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_837 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_838 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_839 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_840 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_841 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_842 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_843 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_844 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_845 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_846 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_847 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_848 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_849 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_850 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_851 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_852 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_853 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_854 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_855 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_856 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_857 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_858 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_859 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_860 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_861 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_862 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_863 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_864 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_865 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_866 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_867 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_868 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_869 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_870 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_871 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_872 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_873 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_874 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_875 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_876 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_877 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_878 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_879 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_880 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_881 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_882 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_883 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_884 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_885 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_886 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_887 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_888 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_889 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_890 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_891 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_892 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_893 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_894 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_895 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_896 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_897 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_898 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_899 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_900 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_901 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_902 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_903 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_904 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_905 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_906 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_907 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_908 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_909 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_910 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_911 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_912 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_913 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_914 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_915 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_916 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_917 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_918 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_919 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_920 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_921 gefunden. Überspringe
# Kein Ordner für Patient Breast_MRI_922 gefunden. Überspringe
# Verteilung abgeschlossen

# %% [markdown]
# ## Ausgabe

# %%
h1 =df[df["Target Hospital"] == hospital_1].count()
h2 =df[df["Target Hospital"] == hospital_2].count()
h3 =df[df["Target Hospital"] == hospital_3].count()
print(f"Target Hospital 1:{h1}")
print(f"Target Hospital 2:{h2}")
print(f"Target Hospital 3:{h3}")
# Out:
# Target Hospital 1:Patient ID               294
# Manufacturer             294
# Bilateral Information    294
# Tumor Location           237
# Target Hospital          294
# dtype: int64
# Target Hospital 2:Patient ID               214
# Manufacturer             214
# Bilateral Information    214
# Tumor Location           214
# Target Hospital          214
# dtype: int64
# Target Hospital 3:Patient ID               414
# Manufacturer             414
# Bilateral Information    414
# Tumor Location           200
# Target Hospital          414
# dtype: int64

# %%
df.to_csv(r"C:\Users\bracke\Documents\df_mit_hospital.csv", index=False)
