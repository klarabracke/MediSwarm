# %%
import os
print(os.getcwd())
# Out:
# c:\Users\bracke\Documents\Masterarbeit\MediSwarm\application\jobs\3dcnn_ptl\app\custom\data\datasets

# %%
import os
print(os.listdir())
# Out:
# ['dataset_3d.py', 'dataset_3d_collab.py', 'dataset_3d_duke.py', 'dataset_3d_duke_external.py', 'dataset_split.py', 'dataset_split2.py', 'dataset_split_2.ipynb', 'dataset_test.ipynb', 'dataset_test.py', 'output_images', 'simple_dataset_3d.py', '__init__.py']

# %%
import os
import shutil
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 import os
#       2 import shutil
# ----> 3 import pandas as pd
#       4 import numpy as np
#
# File c:\Users\bracke\AppData\Local\miniforge3\Lib\site-packages\pandas\__init__.py:151
#     132 from pandas.core.computation.api import eval
#     134 from pandas.core.reshape.api import (
#     135     concat,
#     136     lreshape,
#    (...)    148     qcut,
#     149 )
# --> 151 from pandas import api, arrays, errors, io, plotting, tseries
#     152 from pandas import testing
#     153 from pandas.util._print_versions import show_versions
#
# File c:\Users\bracke\AppData\Local\miniforge3\Lib\site-packages\pandas\api\__init__.py:2
#       1 """ public toolkit API """
# ----> 2 from pandas.api import (
#       3     extensions,
#       4     indexers,
#       5     interchange,
#       6     types,
#       7     typing,
#       8 )
#      10 __all__ = [
#      11     "interchange",
#      12     "extensions",
#    (...)     15     "typing",
#      16 ]
#
# File c:\Users\bracke\AppData\Local\miniforge3\Lib\site-packages\pandas\api\typing\__init__.py:31
#      19 from pandas.core.window import (
#      20     Expanding,
#      21     ExpandingGroupby,
#    (...)     26     Window,
#      27 )
#      29 # TODO: Can't import Styler without importing jinja2
#      30 # from pandas.io.formats.style import Styler
# ---> 31 from pandas.io.json._json import JsonReader
#      32 from pandas.io.stata import StataReader
#      34 __all__ = [
#      35     "DataFrameGroupBy",
#      36     "DatetimeIndexResamplerGroupby",
#    (...)     54     "Window",
#      55 ]
#
# File c:\Users\bracke\AppData\Local\miniforge3\Lib\site-packages\pandas\io\json\__init__.py:1
# ----> 1 from pandas.io.json._json import (
#       2     read_json,
#       3     to_json,
#       4     ujson_dumps,
#       5     ujson_loads,
#       6 )
#       7 from pandas.io.json._table_schema import build_table_schema
#       9 __all__ = [
#      10     "ujson_dumps",
#      11     "ujson_loads",
#    (...)     14     "build_table_schema",
#      15 ]
#
# File c:\Users\bracke\AppData\Local\miniforge3\Lib\site-packages\pandas\io\json\_json.py:71
#      66 from pandas.io.json._normalize import convert_to_line_delimits
#      67 from pandas.io.json._table_schema import (
#      68     build_table_schema,
#      69     parse_table_schema,
#      70 )
# ---> 71 from pandas.io.parsers.readers import validate_integer
#      73 if TYPE_CHECKING:
#      74     from collections.abc import (
#      75         Hashable,
#      76         Mapping,
#      77     )
#
# File c:\Users\bracke\AppData\Local\miniforge3\Lib\site-packages\pandas\io\parsers\__init__.py:1
# ----> 1 from pandas.io.parsers.readers import (
#       2     TextFileReader,
#       3     TextParser,
#       4     read_csv,
#       5     read_fwf,
#       6     read_table,
#       7 )
#       9 __all__ = ["TextFileReader", "TextParser", "read_csv", "read_fwf", "read_table"]
#
# File c:\Users\bracke\AppData\Local\miniforge3\Lib\site-packages\pandas\io\parsers\readers.py:32
#      29 from pandas._config import using_copy_on_write
#      31 from pandas._libs import lib
# ---> 32 from pandas._libs.parsers import STR_NA_VALUES
#      33 from pandas.errors import (
#      34     AbstractMethodError,
#      35     ParserWarning,
#      36 )
#      37 from pandas.util._decorators import Appender
#
# File parsers.pyx:1418, in init pandas._libs.parsers()
#
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_parser_CAPI' (most likely due to a circular import)

# %% [markdown]
# ## Pfade für Verzeichnisse

# %%
image_dir = r"C:\Users\bracke\Documents\all"
excel_path = r"C:\Users\bracke\Documents\all_split\Clinical_and_Other_Features.xlsx"
output_base = r"C:\Users\bracke\Documents\all_split"


hospital_1 = os.path.join(output_base, "Krankenhaus_1")  # M2
hospital_2 = os.path.join(output_base, "Krankenhaus_2")  # M0.1
hospital_3 = os.path.join(output_base, "Krankenhaus_3")  # M0.2


for hospital in [hospital_1, hospital_2, hospital_3]:
    os.makedirs(hospital, exist_ok=True)


df = pd.read_excel(excel_path, header=1)
df = df[["Patient ID", "Manufacturer", "Bilateral Information", "Tumor Location"]]
df.dropna(subset=["Patient ID", "Manufacturer"], inplace=True)

df["Patient ID"] = df["Patient ID"].astype(str).str.strip()  
df["Manufacturer"] = df["Manufacturer"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 15
#      11 for hospital in [hospital_1, hospital_2, hospital_3]:
#      12     os.makedirs(hospital, exist_ok=True)
# ---> 15 df = pd.read_excel(excel_path, header=1)
#      16 df = df[["Patient ID", "Manufacturer", "Bilateral Information", "Tumor Location"]]
#      17 df.dropna(subset=["Patient ID", "Manufacturer"], inplace=True)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ##  Funktion zur Normalisierung der Bilateral-Informationen

# %%
def normalize_bilateral(val):
    if pd.isna(val):
        return "NC"  
    if isinstance(val, str):
        return val.strip().upper()  
    if isinstance(val, (int, float)):
        return int(val)  
    return str(val).upper()  


df["Bilateral Information"] = df["Bilateral Information"].apply(normalize_bilateral)

# %% [markdown]
# ## Zuweisung der Zielkrankenhäuser

# %%
df["Target Hospital"] = None

# Krankenhaus 1: Alle Patienten von Manufacturer 2
df.loc[df["Manufacturer"] == 2, "Target Hospital"] = hospital_1

# Beidseitige Krebsfälle für Krankenhaus 2 (Bilateral Information == 1)
bilateral_cancer_cases = df[(df["Bilateral Information"] == 1) & (df["Manufacturer"] == 0)]

# Einseitige Krebsfälle für Krankenhaus 2 (L-Krebs und R-Krebs)
left_cancer_cases = df[(df["Tumor Location"] == "L") & (df["Manufacturer"] == 0) & (df["Bilateral Information"] == 0)]
right_cancer_cases = df[(df["Tumor Location"] == "R") & (df["Manufacturer"] == 0) & (df["Bilateral Information"] == 0)]

# Zufällige Aufteilung der einseitigen Krebsfälle
n_left = len(left_cancer_cases)
n_right = len(right_cancer_cases)

left_cancer_split = left_cancer_cases.sample(n=n_left//2, random_state=42)  
right_cancer_split = right_cancer_cases.sample(n=int(np.ceil(n_right / 2)), random_state=42)  

# Weisen Sie Krankenhaus 2 für beidseitige Krebsfälle und zufällige L- und R-Krebsfälle zu
df.loc[df["Patient ID"].isin(bilateral_cancer_cases["Patient ID"]), "Target Hospital"] = hospital_2
df.loc[df["Patient ID"].isin(left_cancer_split["Patient ID"]), "Target Hospital"] = hospital_2
df.loc[df["Patient ID"].isin(right_cancer_split["Patient ID"]), "Target Hospital"] = hospital_2

# Krankenhaus 3: Patienten ohne Krebs und die andere Hälfte der einseitigen Krebsfälle
no_cancer = df[(df["Bilateral Information"] == "NC") & (df["Manufacturer"] == 0)]
remaining_left_cancer_cases = left_cancer_cases.drop(left_cancer_split.index)  
remaining_right_cancer_cases = right_cancer_cases.drop(right_cancer_split.index) 

df.loc[df["Patient ID"].isin(no_cancer["Patient ID"]), "Target Hospital"] = hospital_3
df.loc[df["Patient ID"].isin(remaining_left_cancer_cases["Patient ID"]), "Target Hospital"] = hospital_3
df.loc[df["Patient ID"].isin(remaining_right_cancer_cases["Patient ID"]), "Target Hospital"] = hospital_3

# %% [markdown]
# ## Bilder kopieren

# %%
for _, row in df.iterrows():
    patient_id = row["Patient ID"]
    target_dir = row["Target Hospital"]

    if pd.isna(target_dir):
        print(f"Kein Zielkrankenhaus für Patient {patient_id} definiert. Überspringe")
        continue

    matching_folders = [f for f in os.listdir(image_dir) if f.startswith(patient_id[-3:])]
    if not matching_folders:
        print(f"Kein Ordner für Patient {patient_id} gefunden. Überspringe")
        continue

    for folder_name in matching_folders:
        folder_path = os.path.join(image_dir, folder_name)
        src_file = os.path.join(folder_path, "sub.nii.gz")
        if not os.path.exists(src_file):
            print(f"Bild fehlt in {folder_path}. Überspringe")
            continue

    
        patient_subfolder = os.path.join(target_dir, folder_name)
        os.makedirs(patient_subfolder, exist_ok=True)

        dest_file = os.path.join(patient_subfolder, "sub.nii.gz")
        
        if os.path.exists(dest_file):
            print(f"Bild {dest_file} existiert bereits. Überspringe")
            continue

        shutil.copy(src_file, dest_file)
        print(f" Kopiert: {src_file} → {dest_file}")

print("Verteilung abgeschlossen")
# Out:
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\001_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\001_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\002_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\002_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\003_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\003_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\004_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\004_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\005_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\005_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\006_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\006_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\007_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\007_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\008_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\008_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\009_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\009_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\010_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\010_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\011_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\011_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\012_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\012_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\013_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\013_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\014_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\014_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\015_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\015_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\016_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3
right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\192_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\192_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\193_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\193_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\194_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\194_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\195_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\195_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\196_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\196_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\197_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\197_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\198_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\198_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\199_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\199_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\200_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\200_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\201_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\201_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\202_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\202_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\203_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\203_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\204_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\204_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\205_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\205_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\206_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\206_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\207_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\207_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\208_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\208_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\209_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\209_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\210_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\210_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\211_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\211_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\212_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\212_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\213_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\213_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\214_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\214_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\215_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\215_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\216_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\216_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\217_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\217_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\218_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\218_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\219_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\219_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\220_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\220_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\221_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\221_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\222_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\222_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\223_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\223_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\224_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\224_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\225_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\225_right\sub.nii.gz existiert bereits. Überspringe
# ...
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\848_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\848_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\849_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\849_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\850_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\850_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\851_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\851_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\852_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\852_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\853_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\853_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\854_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\854_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\855_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\855_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\856_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\856_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\857_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\857_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\858_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\858_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\859_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\859_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\860_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\860_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\861_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\861_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\862_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\862_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\863_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\863_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\864_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\864_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\865_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\865_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\866_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\866_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\867_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\867_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\868_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\868_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\869_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\869_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\870_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\870_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\871_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\871_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\872_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\872_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\873_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\873_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\874_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\874_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\875_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\875_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\876_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\876_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\877_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\877_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\878_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\878_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\879_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\879_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\880_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\880_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\881_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\881_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\882_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\882_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\883_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\883_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\884_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\884_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\885_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\885_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\886_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\886_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\887_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\887_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\888_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\888_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\889_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\889_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\890_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\890_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\891_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\891_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\892_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\892_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\893_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\893_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\894_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\894_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\895_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\895_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\896_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\896_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\897_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\897_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\898_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\898_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\899_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\899_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\900_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\900_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\901_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\901_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\902_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\902_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\903_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\903_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\904_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\904_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\905_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\905_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\906_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\906_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\907_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\907_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\908_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\908_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\909_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\909_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\910_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\910_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\911_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\911_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\912_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\912_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\913_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\913_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\914_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\914_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\915_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\915_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\916_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\916_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\917_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\917_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\918_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_2\918_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\919_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\919_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\920_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_1\920_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\921_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\921_right\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\922_left\sub.nii.gz existiert bereits. Überspringe
# Bild C:\Users\bracke\Documents\all_split\Krankenhaus_3\922_right\sub.nii.gz existiert bereits. Überspringe
# Verteilung abgeschlossen

# %% [markdown]
# ## Ausgabe

# %%
h1 = df[df["Target Hospital"] == hospital_1].count()
h2 = df[df["Target Hospital"] == hospital_2].count()
h3 = df[df["Target Hospital"] == hospital_3].count()
print(f"Target Hospital 1: {h1}")
print(f"Target Hospital 2: {h2}")
print(f"Target Hospital 3: {h3}")
# Out:
# Target Hospital 1: Patient ID               294
# Manufacturer             294
# Bilateral Information    294
# Tumor Location           237
# Target Hospital          294
# dtype: int64
# Target Hospital 2: Patient ID               214
# Manufacturer             214
# Bilateral Information    214
# Tumor Location           214
# Target Hospital          214
# dtype: int64
# Target Hospital 3: Patient ID               414
# Manufacturer             414
# Bilateral Information    414
# Tumor Location           200
# Target Hospital          414
# dtype: int64

# %%
df.to_csv(r"C:\Users\bracke\Documents\df_mit_hospital.csv", index=False)
